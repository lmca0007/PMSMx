# %% [markdown]
# # Modifications of PMSMx to model magnetostatics
# First, attempt to run the github repository directly inside a docker container.

# %%
import dolfinx, mpi4py, petsc4py
print("Dolfinx:", dolfinx.__version__)
# Out:
# Dolfinx: 0.9.0

# %%
# %run src/pmsm.py
# Out:
# Log init failed: logger with name 'dolfinx' already exists
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /home/fenics/app/src/pmsm.py:317
#     314     log.log(loglevel, "AV: Applying Boundary Conditions")
#     315 bcs_av = []
# --> 317 u0 = Function(V_VF)
#     318 u0.x.petsc_vec.set(0.)
#     319 u0.x.scatter_forward()
#
# File /usr/local/dolfinx-complex/lib/python3.12/dist-packages/dolfinx/fem/function.py:319, in Function.__init__(self, V, x, name, dtype)
#     315     if dtype is None:
#     316         dtype = default_scalar_type
#     318 assert np.issubdtype(
# --> 319     V.element.dtype, np.dtype(dtype).type(0).real.dtype
#     320 ), "Incompatible FunctionSpace dtype and requested dtype."
#     322 # Create cpp Function
#     323 def functiontype(dtype):
#
# AttributeError: 'MixedFunctionSpace' object has no attribute 'element'

# %%
from src import pmsm

pmsm.main()
# Out:
# Log init failed: logger with name 'dolfinx' already exists
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from src import pmsm
#       3 pmsm.main()
#
# File /home/fenics/app/src/pmsm.py:167
#     164 if MPI.COMM_WORLD.rank == 0:
#     165     log.log(loglevel, "Reading Mesh: " + meshpath)
# --> 167 with XDMFFile(MPI.COMM_WORLD,
#     168               meshpath,
#     169               "r",
#     170               encoding=XDMFFile.Encoding.HDF5) as file:
#     171     mesh = file.read_mesh(ghost_mode=GhostMode.none,
#     172                           name="mesh",
#     173                           xpath=r"/Xdmf/Domain")
#     174     mesh.topology.create_connectivity_all()
#
# RuntimeError: Unable to open HDF5 file. File /home/fenics/app/models/mesh1.h5 does not exist.
